# %% [markdown]
# # ANABELLE Backend — One-Click Colab Setup
#
# **Before running:** Runtime → Change runtime type → **GPU** (T4 or better).
#
# This notebook installs all dependencies, downloads model weights + RAVDESS test data, runs the accuracy benchmark, and starts the WebSocket gateway.

# %%
# Clone the repo (update URL if needed)
# !git clone https://github.com/YOUR_ORG/anabelle-backend.git 2>/dev/null || echo "Repo already cloned"
# %cd anabelle-backend

# %%
# One-click setup: deps + models + test data
# !python setup.py --colab

# %%
# Verify GPU is active
import torch
print(f"PyTorch {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# Run static RAVDESS accuracy test
# !python run.py test

# %%
# Start the WebSocket gateway (keep this cell running)
# !python run.py serve
