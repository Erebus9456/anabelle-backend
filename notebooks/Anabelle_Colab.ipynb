# %% [markdown]
# # ANABELLE Backend — One-Click Colab Setup
#
# **Before running:** Runtime → Change runtime type → **GPU** (T4 or better).
#
# Models and test data are stored in `/content/anabelle-data` (outside this repo), so you can `git pull` without re-downloading.

# %%
# Clone once (update URL), or pull on later sessions
import os
REPO = "/content/anabelle-backend"
if not os.path.isdir(REPO):
    # !git clone https://github.com/Erebus9456/anabelle-backend.git {REPO}
else:
    # %cd {REPO}
    # !git pull
# %cd {REPO}

# %%
# Full setup first time; use --skip-models --skip-test-data after git pull
import os
first_run = not os.path.isdir("/content/anabelle-data/models/SenseVoiceSmall")
if first_run:
    # !python setup.py --colab
else:
    # !python setup.py --colab --skip-models --skip-test-data

# %%
import torch
from anabelle.utils.paths import get_data_dir, get_model_dir
print(f"PyTorch {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"Data dir: {get_data_dir()}")
print(f"Model at: {get_model_dir()}")

# %%
# SER smoke test
# !python tests/integration/test_ser.py

# %%
# !python run.py test
# !python run.py serve
